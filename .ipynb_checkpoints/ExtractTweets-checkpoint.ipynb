# %%
import tweepy

# %%
consumer_key = "FQrLvT4yDzE5Twx8d03Rdpa1l" 
#API key:FQrLvT4yDzE5Twx8d03Rdpa1l
consumer_secret = "3vA9zzgN9uWL451kZavLuIyibaZMJmRsLLKoJi2v8jPlchLY6Q"
#API secret key:3vA9zzgN9uWL451kZavLuIyibaZMJmRsLLKoJi2v8jPlchLY6Q
access_key = "1265914852058337280-60VissfwPugxu2n7rKyn7psHVgtj4i"
#access token: 1265914852058337280-60VissfwPugxu2n7rKyn7psHVgtj4i
access_secret = "t4UEpVd0m6YgZuDEn4xNuhw2uOLA6PZlrvw9XMury1rUB"
#access token secret: t4UEpVd0m6YgZuDEn4xNuhw2uOLA6PZlrvw9XMury1rUB

# %%
# Function to extract tweets 
def get_tweets(username): 
    # Authorization to consumer key and consumer secret 
        auth = tweepy.OAuthHandler(consumer_key, consumer_secret) 
  
        # Access to user's access key and access secret 
        auth.set_access_token(access_key, access_secret) 
  
        # Calling api 
        api = tweepy.API(auth) 
  
        # 200 tweets to be extracted 
        number_of_tweets=200
        tweets = api.user_timeline(screen_name=username) 
  
        # Empty Array 
        tmp=[]  
  
        # create array of tweet information: username,  
        # tweet id, date/time, text 
        tweets_for_csv = [tweet.text for tweet in tweets] # CSV file created  
        for j in tweets_for_csv: 
  
            # Appending tweets to the empty array tmp 
            tmp.append(j)  
  
        # Printing the tweets 
        print(tmp)
        

if __name__ == '__main__': 
    get_tweets("weedbiryani")
# Out:
# [Status(_api=<tweepy.api.API object at 0x0000025FE94A6CF8>, _json={'created_at': 'Sat Dec 19 20:00:11 +0000 2020', 'id': 1340386466648653825, 'id_str': '1340386466648653825', 'text': "RT @chaicroissant: i went through all of my playlist's vibes and now i want to get a new music taste", 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'chaicroissant', 'name': '🐸', 'id': 1314819751709876225, 'id_str': '1314819751709876225', 'indices': [3, 17]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1164159642517352449, 'id_str': '1164159642517352449', 'name': 'six drink amy', 'screen_name': 'weedbiryani', 'location': 'Pune, India', 'description': 'I much prefer whining over counting my blessings', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 206, 'friends_count': 222, 'listed_count': 1, 'created_at': 'Wed Aug 21 12:57:55 +0000 2019', 'favourites_count': 4742, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1932, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1338358403379257349/qvGqAEmS_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1338358403379257349/qvGqAEmS_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1164159642517352449/1567511926', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sat Dec 19 17:33:32 +0000 2020', 'id': 1340349562318331904, 'id_str': '1340349562318331904', 'text': "i went through all of my playlist's vibes and now i want to get a new music taste", 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1314819751709876225, 'id_str': '1314819751709876225', 'name': '🐸', 'screen_name': 'chaicroissant', 'location': 's/her • icon & header cr: op', 'description': 'sad but make it funky', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 10, 'friends_count': 35, 'listed_count': 0, 'created_at': 'Sat Oct 10 06:47:39 +0000 2020', 'favourites_count': 774, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 460, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1319961451872743424/GxsLtpVa_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1319961451872743424/GxsLtpVa_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1314819751709876225/1603538308', 'profile_link_color': '1DA1F2', 'profile_sid ...
