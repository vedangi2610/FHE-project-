# %% [markdown]
# <a href="https://colab.research.google.com/github/vedangi2610/FHE-project-/blob/master/interest_vector/test/covidStopwords.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

stopwords_df = pd.read_csv('gdeltunigramstopwordlist-20200708.csv')
# source : https://blog.gdeltproject.org/compiling-a-massive-multilingual-news-based-stopword-list/
stopwords_df.head()
# Out:
#       LANG NGRAM  RANK         CNT
# 0  ENGLISH   the     1  2721816572
# 1  ENGLISH    to     2  1398404958
# 2  ENGLISH   and     3  1337414751
# 3  ENGLISH    of     4  1271584213
# 4  ENGLISH     a     5  1077500772

# %%
df = stopwords_df.loc[stopwords_df['LANG'] == 'ENGLISH']

# %%
df.to_csv('stopwords_english_covid.csv')

# %%
# df.dtypes
# Out:
# LANG     object
# NGRAM    object
# RANK      int64
# CNT       int64
# dtype: object

# %%
stoplist = df['NGRAM'].tolist()
stoplist
# Out:
# ['the',
#  'to',
#  'and',
#  'of',
#  'a',
#  'in',
#  'for',
#  'that',
#  'is',
#  'on',
#  'with',
#  'was',
#  'as',
#  'at',
#  'it',
#  'be',
#  'are',
#  'by',
#  'from',
#  'said',
#  'have',
#  'he',
#  'has',
#  'this',
#  'will',
#  'an',
#  'his',
#  'not',
#  'i',
#  'or',
#  'you',
#  'we',
#  'but',
#  'their',
#  'they',
#  'who',
#  'more',
#  'been',
#  'were',
#  'new',
#  'about',
#  'which',
#  'also',
#  'all',
#  'her',
#  'had',
#  'one',
#  'she',
#  'its',
#  'can',
#  'our',
#  'people',
#  'up',
#  'after',
#  'out',
#  'would',
#  'when',
#  'your',
#  'if',
#  'other',
#  'so',
#  'than',
#  'there',
#  'time',
#  'over',
#  'what',
#  'some',
#  'first',
#  'into',
#  'two',
#  'no',
#  'like',
#  'just',
#  "it's",
#  'year',
#  'may',
#  'last',
#  'them',
#  'do',
#  'now',
#  'years',
#  'my',
#  'could',
#  'state',
#  'how',
#  'us',
#  'get',
#  'any',
#  'while',
#  'only',
#  'most',
#  'during',
#  'being',
#  'through',
#  'where',
# ...

# %%
# Out:
# ['the',
#  'to',
#  'and',
#  'of',
#  'a',
#  'in',
#  'for',
#  'that',
#  'is',
#  'on',
#  'with',
#  'was',
#  'as',
#  'at',
#  'it',
#  'be',
#  'are',
#  'by',
#  'from',
#  'said',
#  'have',
#  'he',
#  'has',
#  'this',
#  'will',
#  'an',
#  'his',
#  'not',
#  'i',
#  'or',
#  'you',
#  'we',
#  'but',
#  'their',
#  'they',
#  'who',
#  'more',
#  'been',
#  'were',
#  'new',
#  'about',
#  'which',
#  'also',
#  'all',
#  'her',
#  'had',
#  'one',
#  'she',
#  'its',
#  'can',
#  'our',
#  'people',
#  'up',
#  'after',
#  'out',
#  'would',
#  'when',
#  'your',
#  'if',
#  'other',
#  'so',
#  'than',
#  'there',
#  'time',
#  'over',
#  'what',
#  'some',
#  'first',
#  'into',
#  'two',
#  'no',
#  'like',
#  'just',
#  "it's",
#  'year',
#  'may',
#  'last',
#  'them',
#  'do',
#  'now',
#  'years',
#  'my',
#  'could',
#  'state',
#  'how',
#  'us',
#  'get',
#  'any',
#  'while',
#  'only',
#  'most',
#  'during',
#  'being',
#  'through',
#  'where',
# ...
