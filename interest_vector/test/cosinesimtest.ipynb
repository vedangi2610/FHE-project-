# %% [markdown]
# <a href="https://colab.research.google.com/github/vedangi2610/FHE-project-/blob/master/cosinesimtest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Used this article as reference for the vectorizing and similarity part- https://www.machinelearningplus.com/nlp/cosine-similarity/

# %%
#Scikit Learn
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
from scipy import spatial
import re
import csv
url = 'https://raw.githubusercontent.com/vedangi2610/FHE-project-/master/data_preprocessing/user_preprocessed_data/preprocess_Atul_Gawande.csv'
user_df = pd.read_csv(url)
user_df.head()
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\sklearn\feature_extraction\image.py:167: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype=np.int):
#    Unnamed: 0                   id      username           created_at lang  \
# 0           0  1388512983899332617  Atul_Gawande  2021-05-01 15:17:47   en
# 1           1  1388347714136682505  Atul_Gawande  2021-05-01 04:21:03   en
# 2           2  1388270433057841155  Atul_Gawande  2021-04-30 23:13:58   en
# 3           3  1388155559778607105  Atul_Gawande  2021-04-30 15:37:30   en
# ...

# %%
def loopforTopics():
  topic = ['Politics', 'Entertainment', 'Healthcare', 'Sports', 'Entrepreneurship', 'ScienceandTech']
  topic_url ='https://raw.githubusercontent.com/vedangi2610/FHE-project-/master/interest_vector/test/preprocessed_topics/preprocess'
  #users=['pilitobar87',  'EwallWice',  'KamenIntheLoop', 'terryshumaker', 'Wake_Up_Mitron', 'amitabhnews18', 'nistula', 'katiewadington', 'stephaniekotuby', 'Nidhi', 'stew_boss', 'DougAndres', 'NMalliotakis', 'SandhuKanwar', 'ShekharGupta', 'mipalkar', 'taran_adarsh', 'PiyaSRoy', 'trilbyberesford', 'collinDcunha', 'vineetkumar_s', 'KimikoGlenn', 'annasmithjourno', 'SteveBPrice', 'sudhirsrinivasn', 'nimishhalkar', 'SPICinemas', 'jrapepper', 'pudiharicharan', 'sheilakathleen', 'katiewalshstx']
  
  #'gabrielle_ake', 'toddlieberman', 'muthoniwambu'

  #users =['mspecter', 'ShamikaRavi', 'engineers_feed', 'wonderofscience', 'DrSidMukherjee', 'anildash', 'thegautamkamath', 'yisongyue', 'beenwrekt', 'CoreyJPeltier', 'randi_c1', 'triketora', 'Atul_Gawande', 'reckless', 'RiyueSunnyBao', 'betenoire1', 'MicrobiomDigest']
  
  #users = ['marshsutherland', 'dvasishtha', 'warikoo', 'malpani', 'MoodyKhedr', 'KarinaCBell', 'e2org', 'MacConwell', 'alexdtang', 'Jai__Malik', 'jasonlk', 'mattturck', 'MrAllenMiller', 'oakhcft', 'zabackj', 'EghosaO', 'andi_staub']

  #users = ['buissonnierem', 'DocVatsa', 'GidMK', 'GorwayGlobal', 'ZoeMcLaren', 'DiseaseEcology', 'DrMaurieMarkman', 'jlkowalik', 'Neuro_Skeptic', 'eatright','DoctorLFC', 'JasonRobertsRD', 'MartinKulldorff', 'BornFitness']

  #http error : UriCohen42, AyushmanHWCs

   #'rssharma3' preprocessing error float object not iterable

  #users = ['paigebueckers1', 'BeardAndBoujeee', 'mikeyfish1982', 'adamboultwood', 'edgbaston__149', 'Devanayagam', 'ToastedChels', 'abbstace', 'WtephenWurrySZN', 'sign_up1029', 'YeshwantChitte', 'TennisPuneet', 'jimmy9toes', 'TonyWurtzSK', 'malavshroff', 'gathogo_kennedy', 'rakeshrussell52' ]

  users = ['pilitobar87',  'EwallWice',  'KamenIntheLoop', 'terryshumaker', 'Wake_Up_Mitron', 'amitabhnews18', 'nistula', 'katiewadington', 'stephaniekotuby', 'Nidhi', 'stew_boss', 'DougAndres', 'NMalliotakis', 'SandhuKanwar', 'ShekharGupta', 'mipalkar', 'taran_adarsh', 'PiyaSRoy', 'trilbyberesford', 'collinDcunha', 'vineetkumar_s', 'KimikoGlenn', 'annasmithjourno', 'SteveBPrice', 'sudhirsrinivasn', 'nimishhalkar', 'SPICinemas', 'jrapepper', 'pudiharicharan', 'sheilakathleen', 'katiewalshstx', 'mspecter', 'ShamikaRavi', 'engineers_feed', 'wonderofscience', 'DrSidMukherjee', 'anildash', 'thegautamkamath', 'yisongyue', 'beenwrekt', 'CoreyJPeltier', 'randi_c1', 'triketora', 'Atul_Gawande', 'reckless', 'RiyueSunnyBao', 'betenoire1', 'MicrobiomDigest', 'marshsutherland', 'dvasishtha', 'warikoo', 'malpani', 'MoodyKhedr', 'KarinaCBell', 'e2org', 'MacConwell', 'alexdtang', 'Jai__Malik', 'jasonlk', 'mattturck', 'MrAllenMiller', 'oakhcft', 'zabackj', 'EghosaO', 'andi_staub','buissonnierem', 'DocVatsa', 'GidMK', 'GorwayGlobal', 'ZoeMcLaren', 'DiseaseEcology', 'DrMaurieMarkman', 'jlkowalik', 'Neuro_Skeptic', 'eatright','DoctorLFC', 'JasonRobertsRD', 'MartinKulldorff', 'BornFitness', 'paigebueckers1', 'BeardAndBoujeee', 'mikeyfish1982', 'adamboultwood', 'edgbaston__149', 'Devanayagam', 'ToastedChels', 'abbstace', 'WtephenWurrySZN', 'sign_up1029', 'YeshwantChitte', 'TennisPuneet', 'jimmy9toes', 'TonyWurtzSK', 'malavshroff', 'gathogo_kennedy', 'rakeshrussell52', 'JMullinsGrissom', 'revathii95', 'RuhiTewari' , 'viewfinderfc' , 'FHF_Official' , 'lisaschwarzbaum', 'zlatko_minev', 'tanyabasu', 'astrocaits', 'garyvee' , 'mcuban', 'philipvandusen', 'michaelmina_lab', 'cmyeaton', 'ashishkjha'
,'ChrisHammer180', 'Richard_Mann11', 'nassercricket']
 
  user_url = 'https://raw.githubusercontent.com/vedangi2610/FHE-project-/master/interest_vector/test/preprocessed_user/preprocess_'

  file_name = 'stopwords_interest_vector.csv'       
  csvFile = open(file_name, 'a', encoding="utf-8")
  csvWriter = csv.writer(csvFile)
  '''To check if file exists'''
  try: 
      pd.read_csv(file_name)
  except pd.errors.EmptyDataError:
      csvWriter.writerow(["username","interest_vector","Politics", "Entertainment", "Healthcare", "Sports", "Entrepreneurship", "ScienceandTech"])


  for u in users:
    url1 = user_url +u+ '.csv'
    print(url1)
    userstring = lemmastoString(url1)
    user_list = []
    for t in topic: 
      url2 = topic_url +t+'.csv'
      #print(url2)
      topicstring = lemmastoString(url2)
      document = [userstring, topicstring]
      val = calculate_cosine_sim(document)
      user_list.append(val)
      # print(document[0])
      # print(document[1])
      print(t+" "+str(val))
      #print(user_list)
    csvWriter.writerow([u,user_list, user_list[0], user_list[1], user_list[2], user_list[3], user_list[4],user_list[5]])
  csvFile.close()

loopforTopics()
# Out:
# https://raw.githubusercontent.com/vedangi2610/FHE-project-/master/interest_vector/test/preprocessed_user/preprocess_pilitobar87.csv
# Politics 0.13
# Entertainment 0.05
# Healthcare 0.3
# Sports 0.06
# Entrepreneurship 0.08
# ScienceandTech 0.08
# https://raw.githubusercontent.com/vedangi2610/FHE-project-/master/interest_vector/test/preprocessed_user/preprocess_EwallWice.csv
# Politics 0.16
# Entertainment 0.05
# Healthcare 0.35
# Sports 0.07
# Entrepreneurship 0.07
# ScienceandTech 0.07
# https://raw.githubusercontent.com/vedangi2610/FHE-project-/master/interest_vector/test/preprocessed_user/preprocess_KamenIntheLoop.csv
# Politics 0.12
# Entertainment 0.06
# Healthcare 0.41
# Sports 0.09
# Entrepreneurship 0.08
# ScienceandTech 0.12
# https://raw.githubusercontent.com/vedangi2610/FHE-project-/master/interest_vector/test/preprocessed_user/preprocess_terryshumaker.csv
# Politics 0.14
# Entertainment 0.05
# Healthcare 0.33
# Sports 0.08
# Entrepreneurship 0.08
# ScienceandTech 0.07
# ...

# %%
# !pip install validators
import validators
users = ['paigebueckers1', 'BeardAndBoujeee', 'mikeyfish1982', 'adamboultwood', 'edgbaston__149', 'Devanayagam', 'ToastedChels', 'abbstace', 'WtephenWurrySZN', 'sign_up1029', 'YeshwantChitte', 'TennisPuneet', 'jimmy9toes', 'TonyWurtzSK', 'malavshroff', 'gathogo_kennedy', 'rakeshrussell52' ]

user_url = 'https://raw.githubusercontent.com/vedangi2610/FHE-project-/master/data_preprocessing/user_preprocessed_data/preprocess_'

for u in users:
  url1 = user_url +u+ '.csv'
  valid=validators. url(url1)
  if valid != True:
    print(u+" Invalid url")

valid=validators. url('https://raw.githubusercontent.com/vedangi2610/FHE-project-/master/data_preprocessing/user_preprocessed_data/preprocess_gabrielle_ake.csv')
print(valid)
# Out:
# ...
# True

# %%
def pre_process(text):
    #print (text)
    text = ''.join([str(elem) for elem in text])
    #print (text)
    # lowercase
    text=text.lower()
    
    #remove tags
    text=re.sub("","",text)
    
    # remove special characters and digits
    text=re.sub("(\\d|\\W)+"," ",text)
    
    return text

#df_idf['text'] = df_idf['title'] + df_idf['body']
user_df['wordlist'] = user_df['lemmas'].apply(lambda x:pre_process(x))
user_df['wordlist'].head()
# Out:
# 0                             highly recommend thread
# 1     ashishkjha today india nation pass k case day...
# 2     not way indias southern states kerala tamil n...
# 3     succinct distressing update state india covid...
# 4     agree precisely kind concrete assistance need...
# Name: wordlist, dtype: object

# %%
def lemmastoString(url):
  user_df = pd.read_csv(url)
  # user_df.head()
  user_df['wordlist'] = user_df['lemmas'].apply(lambda x:pre_process(x))
  # user_df['wordlist'].head()
  userstring=""
  #adding words to string
  for l in user_df['wordlist']:
    userstring = userstring + str(l)
  # print(userstring)
  #removing extra spaces
  userstring=userstring.replace("  ", " ")
  # print(userstring)
  return userstring

# %%
def calculate_cosine_sim(documents):
  # Create the Document Term Matrix
  count_vectorizer = CountVectorizer(stop_words='english')
  count_vectorizer = CountVectorizer()
  sparse_matrix = count_vectorizer.fit_transform(documents)

  # OPTIONAL: Convert Sparse Matrix to Pandas Dataframe if you want to see the word frequencies.
  doc_term_matrix = sparse_matrix.todense()
  df = pd.DataFrame(doc_term_matrix, 
                    columns=count_vectorizer.get_feature_names(), 
                    index=['user_string', 'topic'])
  
  # Since the cosine similarity metric returns a 2d matrix and we need a single value
  cosine_similarity = 1 - spatial.distance.cosine(doc_term_matrix[0], doc_term_matrix[1])
  cosine_similarity = round (cosine_similarity, 2) #rounding to 2 dp
  return cosine_similarity

# %%
user_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1199 entries, 0 to 1198
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      1199 non-null   int64
#  1   id              1199 non-null   int64
#  2   username        1199 non-null   object
#  3   created_at      1199 non-null   object
#  4   lang            1199 non-null   object
#  5   cleaned_tweets  1184 non-null   object
#  6   favorite_count  1199 non-null   int64
#  7   retweet_count   1199 non-null   int64
#  8   text            1199 non-null   object
#  9   tokens          1199 non-null   object
#  10  lemmas          1199 non-null   object
#  11  wordlist        1199 non-null   object
# dtypes: int64(4), object(8)
# memory usage: 112.5+ KB

# %%
userstring=""
for l in user_df['wordlist']:
  userstring = userstring + str(l)
print(userstring)
# Out:
#  highly recommend thread  ashishkjha today india nation pass k case day k test death true infection death l  not way indias southern states kerala tamil nadu decade better ru  succinct distressing update state india covid crisis  agree precisely kind concrete assistance need immediate effect effect week  bhramarbiostat right regardless model know tidal wave hit picket fence beat need  hospital sir gangaram delhis great hospitalsa place visit surgeonand  delhi hospital covid patient oxygen nearly oxygen supply  oxygen level guard balrampur hospital let enter disturb pi  good  oop mean kakape  kakapo stats advisory meeting rare  vote recommend lift long pause jnj vaccine add warn rare case cause cl  clear vaccination rate hcw setting acceptable case tell require  vaccine effectiveness symptomatic infection protection death clearly nursin  let unpack detail q vax doses pfizer work absolutely remarkable perfec  outbreak vital understand show face young folk unvaccinated health  apoorvany
# ...

# %%
#removing extra spaces 
userstring=userstring.replace("  ", " ")
print(userstring)
# Out:
#  highly recommend thread ashishkjha today india nation pass k case day k test death true infection death l not way indias southern states kerala tamil nadu decade better ru succinct distressing update state india covid crisis agree precisely kind concrete assistance need immediate effect effect week bhramarbiostat right regardless model know tidal wave hit picket fence beat need hospital sir gangaram delhis great hospitalsa place visit surgeonand delhi hospital covid patient oxygen nearly oxygen supply oxygen level guard balrampur hospital let enter disturb pi good oop mean kakape kakapo stats advisory meeting rare vote recommend lift long pause jnj vaccine add warn rare case cause cl clear vaccination rate hcw setting acceptable case tell require vaccine effectiveness symptomatic infection protection death clearly nursin let unpack detail q vax doses pfizer work absolutely remarkable perfec outbreak vital understand show face young folk unvaccinated health apoorvanyc break pfizer bi
# ...

# %%
url = 'https://raw.githubusercontent.com/vedangi2610/FHE-project-/master/data_preprocessing/preprocessPolitics.csv'
pol_df = pd.read_csv(url)
pol_df.head()
# Out:
#    Unnamed: 0  ...                                             lemmas
# 0           0  ...  ['seventh', 'phase', 'west', 'bengal', 'electi...
# 1           1  ...                                                 []
# 2           2  ...  ['oxygen', 'plant', 'district', 'ensure', 'ade...
# 3           3  ...                    ['tune', 'mannkibaat', 'april']
# 4           4  ...                                                 []
#
# [5 rows x 11 columns]

# %%
#converting to words
pol_df['wordlist'] = pol_df['lemmas'].apply(lambda x:pre_process(x))
pol_df['wordlist'].head()
# Out:
# 0     seventh phase west bengal election take place...
# 1
# 2     oxygen plant district ensure adequate oxygen ...
# 3                               tune mannkibaat april
# 4
# Name: wordlist, dtype: object

# %%
polstring=""
for l in pol_df['wordlist']:
  polstring = polstring + str(l)
print(polstring)
# Out:
#  seventh phase west bengal election take place today urge people exercise franchise fol   oxygen plant district ensure adequate oxygen availability important decision boost ox  tune mannkibaat april   high level meeting key decision waive custom duty oxygen oxygen relate equipment covid  address programme panchayatirajdiwas watch  today special occasion panchayatirajdiwas distribution e property card svamitva sche  earlier today meet lead oxygen manufacturer country discuss effort scale oxygen supply  address virtual rally west bengal election  discuss covid situation chief minister state see surge infection discuss  tomorrow chair high level meeting review prevail covid situation  todays high level meet review situation relate oxygen supply way boost oxyge  condolence shri sitaram yechury ji family tragic untimely demise son ashish om shanti  sadden pass away maulana wahiduddin khan remember insightful knowledge matt  people west bengal voting elect new assembly sixth phase today ur
# ...

# %%
#removing extra spaces 
poltring=polstring.replace("  ", " ")
print(polstring)
# Out:
#  seventh phase west bengal election take place today urge people exercise franchise fol   oxygen plant district ensure adequate oxygen availability important decision boost ox  tune mannkibaat april   high level meeting key decision waive custom duty oxygen oxygen relate equipment covid  address programme panchayatirajdiwas watch  today special occasion panchayatirajdiwas distribution e property card svamitva sche  earlier today meet lead oxygen manufacturer country discuss effort scale oxygen supply  address virtual rally west bengal election  discuss covid situation chief minister state see surge infection discuss  tomorrow chair high level meeting review prevail covid situation  todays high level meet review situation relate oxygen supply way boost oxyge  condolence shri sitaram yechury ji family tragic untimely demise son ashish om shanti  sadden pass away maulana wahiduddin khan remember insightful knowledge matt  people west bengal voting elect new assembly sixth phase today ur
# ...

# %%
documents = [userstring, polstring]

# %%
#Scikit Learn
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd

# Create the Document Term Matrix
count_vectorizer = CountVectorizer(stop_words='english')
count_vectorizer = CountVectorizer()
sparse_matrix = count_vectorizer.fit_transform(documents)

# OPTIONAL: Convert Sparse Matrix to Pandas Dataframe if you want to see the word frequencies.
doc_term_matrix = sparse_matrix.todense()
df = pd.DataFrame(doc_term_matrix, 
                  columns=count_vectorizer.get_feature_names(), 
                  index=['user_string', 'pol_topic'])
print(df)
# Out:
#              aa  aaa  aaajatlanta  aadmi  ...  zulfiker  zumamabu  zydus  zysz
# user_string   1    0            0      0  ...         0         0      0     0
# pol_topic     2    1            1     15  ...         1         2      1     1
#
# [2 rows x 25026 columns]

# %%
print(df.trump)
# Out:
# user_string      26
# pol_topic      3086
# Name: trump, dtype: int64

# %% [markdown]
# YES THIS CORRELATES TO OUR VOCAB COUNT ALSO??!!!

# %%
print(doc_term_matrix)
# Out:
# [[1 0 0 ... 0 0 0]
#  [2 1 1 ... 2 1 1]]

# %%
print(sparse_matrix) #(ROW NO, COLUMN NO) AND THE FREQUENCY COUNT SUMMED I THINK?
# Out:
#   (0, 9772)	4
#   (0, 18292)	5
#   (0, 22514)	27
#   (0, 1521)	17
#   (0, 22680)	32
#   (0, 10538)	8
#   (0, 14940)	2
#   (0, 16349)	4
#   (0, 3513)	74
#   (0, 5458)	54
#   (0, 22241)	62
#   (0, 5516)	64
#   (0, 23027)	7
#   (0, 10661)	14
#   (0, 15456)	43
#   (0, 24360)	15
#   (0, 10572)	1
#   (0, 20881)	3
#   (0, 21195)	13
#   (0, 12068)	1
#   (0, 21973)	1
#   (0, 14823)	1
#   (0, 5540)	4
#   (0, 2425)	4
#   (0, 19207)	2
#   :	:
#   (1, 9604)	1
#   (1, 5315)	1
#   (1, 14847)	1
#   (1, 22600)	1
#   (1, 17279)	1
#   (1, 11731)	1
#   (1, 14980)	1
#   (1, 19284)	1
#   (1, 4549)	1
#   (1, 14825)	1
#   (1, 3379)	1
#   (1, 21937)	1
#   (1, 13323)	1
#   (1, 230)	1
#   (1, 7919)	1
#   (1, 6867)	1
#   (1, 491)	1
#   (1, 18454)	1
#   (1, 6048)	1
#   (1, 6704)	1
#   (1, 8532)	1
#   (1, 13915)	1
#   (1, 12623)	1
#   (1, 4959)	1
#   (1, 1286)	1

# %%
# Since the cosine similarity metric returns a 2d matrix and we need a single value
from scipy import spatial
#cosine sim value = 1-spatial distance
cosine_similarity = 1 - spatial.distance.cosine(doc_term_matrix[0], doc_term_matrix[1])
cosine_similarity = round (cosine_similarity, 2) #rounding to 2 dp
print(cosine_similarity)
# Out:
# 0.54

# %% [markdown]
# This shows the user has 0.53 interest in politics, basically 53%

# %% [markdown]
# BELOW TRIED USING WORD EMBEDDING (AS PER ARTICLE)

# %%
import gensim
# upgrade gensim if you can't import softcossim
from gensim.matutils import softcossim 
from gensim import corpora
import gensim.downloader as api
from gensim.utils import simple_preprocess
print(gensim.__version__)
#> '3.6.0'

# Download the FastText model
fasttext_model300 = api.load('fasttext-wiki-news-subwords-300')
# Out:
# 3.6.0
# [==================================================] 100.0% 958.5/958.4MB downloaded

# %%
# Prepare a dictionary and a corpus.
dictionary = corpora.Dictionary([simple_preprocess(doc) for doc in documents])

# Prepare the similarity matrix
similarity_matrix = fasttext_model300.similarity_matrix(dictionary, tfidf=None, threshold=0.0, exponent=2.0, nonzero_limit=100)

# Convert the sentences into bag-of-words vectors.
sent_1 = dictionary.doc2bow(simple_preprocess(userstring))
sent_2 = dictionary.doc2bow(simple_preprocess(polstring))
sentences = [sent_1, sent_2]

# Compute soft cosine similarity
print(softcossim(sent_1, sent_2, similarity_matrix))

# %% [markdown]
# This method shows 75% similarity which seems better? i guess we'll need to compare the scores we get from other topics too to know for sure
